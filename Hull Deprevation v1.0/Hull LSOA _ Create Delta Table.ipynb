# %%
df = spark.read.format("csv").option("header","true").load("Files/RAW_2019-deprivation-by-postcode.csv")
# df now is a Spark DataFrame containing CSV data from "Files/Dataset_Value_Interpolation.csv".
display(df)
# Out:
# StatementMeta(, 54b35be6-21b9-4c7c-a318-fd10b153435c, 3, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, badd4817-9d84-4cec-b088-62b9c76d186d)

# %%
df_new.write.format("delta").mode("overwrite").saveAsTable("RAW_2019-deprivation-by-postcode")
# Out:
# StatementMeta(, 702a6a43-3fd0-40de-9858-225db3251dfd, 11, Finished, Available, Finished)
